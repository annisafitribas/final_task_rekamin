# %% [markdown]
# <a href="https://colab.research.google.com/github/annisafitribas/final_task_rekamin/blob/main/final_task_rekamin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load data

# %%
# File IDs
train_id = "1q059QolR6CNxB0PWESAjkEWIprNutajA"
test_id  = "1QD7ehk_hzXze0vHQuYa5qyqfDcfI8Sex"

# Generate direct link otomatis
url_train = f"https://drive.google.com/uc?id={train_id}"
url_test  = f"https://drive.google.com/uc?id={test_id}"

# Load dataset
train = pd.read_csv(url_train)
test  = pd.read_csv(url_test)

print("Train shape:", train.shape)
print("Test shape :", test.shape)

# train.head()
# Out:
# Train shape: (0, 3)
# Test shape : (48744, 121)

# %% [markdown]
# # Quick EDA checks (target, missing, dtypes)

# %%
from pandas._libs import missing
# Target
print(train['Target'].value_counts(normalize=True))
print(train['Target']).value_counts()

# Missing Value
missing = train.isna().mean().sort_values(ascending=False).head(30)
print(missing)

# Dtypes
print(train.types.value_counts())

train.simple(5, random_state=42)
